# %%
import pandas as pd

df = pd.read_csv("../datasets/v5/train_split.csv")

# %%
import py3Dmol 

domain_index = 99
protein_id = df["protein_id"][domain_index]
domain_start = df["domain_start"][domain_index]
domain_end = df["domain_end"][domain_index]


view = py3Dmol.view(query='pdb:' + protein_id) 
view.setStyle({'cartoon':{'color':'white'}}) 
view.addStyle({'resi': f"{domain_start}-{domain_end}"}, {'cartoon': {'color': 'blue'}})

view
# Out:
# <div id="3dmolviewer_1750859717942435"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_1750859717942435" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1750859717942435 = null;
# var warn = document.getElementById("3dmolwarning_1750859717942435");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1750859717942435 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1750859717942435"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5zai", viewer_1750859717942435, {}, function() {
# viewer_1750859717942435.zoomTo();
# 	viewer_1750859717942435.setStyle({"cartoon": {"color": "white"}});
# 	viewer_1750859717942435.addStyle({"resi": "202-257"},{"cartoon": {"color": "blue"}});
# viewer_1750859717942435.render();
# })
# });
# </script>
